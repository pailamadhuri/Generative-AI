# %%
import os
import getpass
from openai import OpenAI
api_key = getpass.getpass("Enter OpenAI API key: ")
client = OpenAI(api_key=api_key)
# Out:
# Enter OpenAI API key: ··········

# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-mini",
    input="Write a 3-line welcome message for a new employee joining a software team."
)

print(response.output_text)
# Out:
# Welcome to the team! We’re excited to have you join us and look forward to the ideas and energy you’ll bring.
# You’ll find a collaborative group here that loves solving problems, learning together, and building great software.
# If you ever need help, have questions, or just want to connect, we’re always glad to support you.

# %%
from openai import OpenAI

# client = OpenAI()

response = client.responses.create(
    model="gpt-5",
    input="Tranlate it into Hindi and telugu-iam feeling very tired today"
)

print(response.output_text)
# Out:
# - Hindi:
#   - (male) आज मैं बहुत थका हुआ महसूस कर रहा हूँ।
#   - (female) आज मैं बहुत थकी हुई महसूस कर रही हूँ।
#
# - Telugu:
#   - ఈ రోజు నాకు చాలా అలసటగా ఉంది।
#   - లేదా: నేను ఈ రోజు చాలా అలసిపోయాను।

# %%
from openai import OpenAI

# client = OpenAI()

response = client.responses.create(
    model="gpt-5",
    input=
    "Translate it into Hindi and telugu-instead of asking the model to guess from memory RAG does this Search for relevant information from documents Give that information to the model"

)

print(response.output_text)
# Out:
# Hindi:
# - मॉडल से याददाश्त के आधार पर अनुमान लगाने के बजाय, RAG यह करता है:
#   - दस्तावेज़ों से प्रासंगिक जानकारी खोजता है
#   - उस जानकारी को मॉडल को उपलब्ध कराता है
#
# Telugu:
# - మోడల్‌ను జ్ఞాపకశక్తి ఆధారంగా ఊహించమని అడగడంకన్నా, RAG ఇలా చేస్తుంది:
#   - పత్రాల నుండి సంబంధిత సమాచారాన్ని శోధిస్తుంది
#   - ఆ సమాచారాన్ని మోడల్‌కు అందిస్తుంది

# %%
#Text creation
response = client.responses.create(
    model="gpt-5",
    input="""
    Write a friendly product description for a smart water bottle.
    Keep it under 80 words.
    """
)
print(response.output_text)
# Out:
# Meet the Hydrago Smart Bottle: your daily hydration coach. It tracks every sip, glows to remind you to drink, and syncs with your phone to set personalized goals. Double-wall stainless steel keeps water cold 24 hours, hot 12. A touch-cap shows progress, while the leakproof, BPA-free design fits any cup holder. Long-lasting rechargeable battery and dishwasher-safe lid make staying hydrated simple, smart, and stylish.

# %%
#B) Manipulate text

#Example: rewrite professionally
response = client.responses.create(
    model="gpt-5",
    input="""
    Rewrite this message in a professional tone:

    "Hey team, we messed up the rollout. Need to fix it today."
    """
)
print(response.output_text)
# Out:
# Team, we identified issues with the rollout and need to resolve them today. Please prioritize the fix.

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Write a short Instagram caption about life"
)

print(response.output[0].content[0].text)
# Out:
# Life isn’t perfect, but it’s full of beautiful moments. 🌱✨ #Grateful #EnjoyTheJourney

# %%
from openai import OpenAI
client = OpenAI()

result = client.images.generate(
    model="gpt-image-1",   # DALL·E-style image model
    prompt="A cute puppy playing in the snow, cartoon style"
)

image_base64 = result.data[0].b64_json

# %%
from openai import OpenAI
client = OpenAI()

result = client.images.generate(
    model="gpt-image-1",   # DALL·E-style image model
    prompt="A cute puppy playing in the snow, cartoon style"
)

image_base64 = result.data[0].b64_json

# %%
import base64
from IPython.display import display, Image

# Decode base64 to bytes
image_bytes = base64.b64decode(image_base64)

# Display image in notebook
display(Image(data=image_bytes))

# %%
result = client.images.generate(
    model="gpt-image-1",
    prompt="A futuristic robot cooking in a kitchen, high detail, realistic"
)
image_base64 = result.data[0].b64_json
import base64
from IPython.display import display, Image

# Decode base64 to bytes
image_bytes = base64.b64decode(image_base64)

# Display image in notebook
display(Image(data=image_bytes))

# %%
#text to speech
from openai import OpenAI

client = OpenAI()

speech = client.audio.speech.create(
    model="gpt-4o-mini-tts",
    voice="alloy",
    input="Our quarterly meeting covered revenue growth, hiring delays, and a product launch scheduled for next month. The team agreed to reduce scope for the first release."
)

speech.stream_to_file("speech.mp3")
print("Audio saved as speech.mp3")
# Out:
# Audio saved as speech.mp3
# /tmp/ipykernel_3120/3812592416.py:12: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   speech.stream_to_file("speech.mp3")

# %%
from IPython.display import Audio

Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#speech to text
audio_file = open("speech.mp3", "rb")

transcript = client.audio.transcriptions.create(
    model="gpt-4o-transcribe",
    file=audio_file
)

print(transcript.text)
# Out:
# Our quarterly meeting covered revenue growth, hiring delays, and a product launch scheduled for next month. The team agreed to reduce scope for the first release.

# %%
#Image Generation Using DALL-E
import os
import json
import base64
import io
import time
import uuid
#from IPython.dispaly import Image,display
from PIL import Image as PILImage
from pathlib import Path

# %%
os.environ["OPENAI_API_KEY"] = "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"
client=OpenAI()

# %%
response=client.images.generate(
    prompt="A Duck against the backdrop of a vibrantnand breathtaking sunset",
    n=1,
    size="256x256"
)
response
# Out:
# ImagesResponse(created=1777877785, background=None, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0En3ANl3Umhb64EEmSsIPtc/user-qtYdijziFQBxSypWl6heZD32/img-KnOsAgup9MTcV3BrgDH5H6UP.png?st=2026-05-04T05%3A56%3A25Z&se=2026-05-04T07%3A56%3A25Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-03T19%3A27%3A34Z&ske=2026-05-04T19%3A27%3A34Z&sks=b&skv=2026-02-06&sig=WY6BPDxcNDKCZx1IjQBChh%2BqFyWuBAxjGvLSwlmXUpc%3D')], output_format=None, quality=None, size=None, usage=None)

# %%
Image(url=response.data[0].url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0En3ANl3Umhb64EEmSsIPtc/user-qtYdijziFQBxSypWl6heZD32/img-KnOsAgup9MTcV3BrgDH5H6UP.png?st=2026-05-04T05%3A56%3A25Z&se=2026-05-04T07%3A56%3A25Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-03T19%3A27%3A34Z&ske=2026-05-04T19%3A27%3A34Z&sks=b&skv=2026-02-06&sig=WY6BPDxcNDKCZx1IjQBChh%2BqFyWuBAxjGvLSwlmXUpc%3D"/>

# %%
response=client.images.generate(
    prompt="A flamingo playing cricket in a beautiful green field",
    n=1,
    size="256x256",
    response_format="b64_json"
)
response
# Out:
# ImagesResponse(created=1777877801, background=None, data=[Image(b64_json='...', revised_prompt=None, url=None)], output_format=None, quality=None, size=None, usage=None)

# %%
image_data=base64.b64decode(response.data[0].b64_json)
image=PILImage.open(io.BytesIO(image_data))
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
import base64

from PIL import Image as PILImage

client=OpenAI()

result = client.images.generate(

prompt="cat image",

model ="dall-e-3",

size="1024x1024",

style="natural",

quality="hd"

)

from IPython.display import Image

Image(url=result.data[0].url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0En3ANl3Umhb64EEmSsIPtc/user-qtYdijziFQBxSypWl6heZD32/img-dzUJtm3xNSFJxaXOEVCukAKS.png?st=2026-05-04T05%3A58%3A31Z&se=2026-05-04T07%3A58%3A31Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=7daae675-7b42-4e2e-ab4c-8d8419a28d99&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-05-03T15%3A35%3A32Z&ske=2026-05-04T15%3A35%3A32Z&sks=b&skv=2026-02-06&sig=Pxm5CdtaTe9LJnaa5HQxlGxqpGq1JqwY7QINjAECBf0%3D"/>
